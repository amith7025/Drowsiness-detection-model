# %%
import os
from pathlib import Path

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_path = Path('/content/drive/MyDrive/datas/images')

# %%
image_list = list(dir_path.glob('*.jpg'))

# %%
image_list
# Out:
# [PosixPath('/content/drive/MyDrive/datas/images/1695380660371.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660389.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660385.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660393.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660420.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660382.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660367.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660442.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660349.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660432.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660344.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660401.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660424.jpg'),
#  PosixPath('/content/drive/MyDrive/datas/images/1695380660409.jpg'),
# ...

# %%
import PIL.Image as Image
import random

# %%
img = Image.open(random.choice(image_list))
img.height,img.width
# Out:
# (2592, 1944)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img_array = np.array(img)
plt.imshow(img_array)
plt.axis(False)
# Out:
# (-0.5, 1943.5, 2591.5, -0.5)

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15994, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15994 (delta 18), reused 18 (delta 12), pack-reused 15967
# Receiving objects: 100% (15994/15994), 14.58 MiB | 24.16 MiB/s, done.
# Resolving deltas: 100% (10984/10984), done.

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s').to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# requirements: Ultralytics requirement ['gitpython>=3.1.30'] not found, attempting AutoUpdate...
# ...

# %%
# !cd yolov5 && python train.py --img 640 --batch-size 4 --epochs 70 --data drowsiness_data.yaml --weights yolov5s.pt
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5s.pt, cfg=, data=drowsiness_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=70, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# requirements: Ultralytics requirement ['thop>=0.1.1'] not found, attempting AutoUpdate...
# ...
#
# requirements: AutoUpdate success ✅ 5.0s, installed 1 package: ['thop>=0.1.1']
# ...

# %%
# !cd yolov5 && python train.py --img 640 --batch-size 8 --epochs 50 --data drowsiness_data.yaml --weights yolov5s.pt
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5s.pt, cfg=, data=drowsiness_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
import shutil

# Specify the name of the folder you want to zip
folder_name = "yolov5"

# Specify the name of the ZIP file you want to create
zip_file_name = "drowsiness"

# Create a ZIP file containing the folder and its contents
shutil.make_archive(zip_file_name, 'zip', folder_name)
# Out:
# '/content/drowsiness.zip'

# %%
import os

# %%
img1 = os.path.join('drive','MyDrive','datas','images','1695380660344.jpg')
img2 = os.path.join('drive','MyDrive','datas','images','/content/drive/MyDrive/datas/images/1695380660385.jpg')

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path='/content/yolov5/runs/train/exp2/weights/best.pt',force_reload=True).to('cuda')
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 2023-9-23 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
results = model(img2)
print(results)
# Out:
# image 1/1: 2592x1944 1 sleep
# Speed: 47.9ms pre-process, 8.8ms inference, 1.5ms NMS per image at shape (1, 3, 640, 480)

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
